# %% [markdown]
# <a href="https://colab.research.google.com/github/hariharan-leela/UKVI-Compliance/blob/main/Edit_of_first_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import load_workbook
wb = load_workbook("/File.Classification.Full.Data.xlsx")
sheet = wb.active

classification = []
file_names = []
columns = sheet["A"]
for data in columns:
    file_names.append(data.value)
    if ".mp4" in data.value:
        classification.append("Interview Recording")
    elif "cv" in data.value:
        classification.append("CV")
    elif "resume" in data.value:
        classification.append("CV")
    elif "passport" in data.value:
        classification.append("Certified Passport(front & back)")
    elif "brp" in data.value:
        classification.append("Certified BRP(front & back)")
    elif "starter form" in data.value:
        classification.append("Starter Form")
    elif "pension" in data.value:
        classification.append("Pension Form")
    elif "addendum" in data.value:
        classification.append("Addendum Signed")
    elif "compliance undertaking" in data.value:
        classification.append("Compliance Undertaking")
    elif "job description" in data.value:
        classification.append("Job Description")
    elif "rtwc" in data.value:
        classification.append("RTWC online/offline form")
    elif "offer letter" in data.value:
        classification.append("Signed Offer Letter")
    elif "approval" in data.value:
        classification.append("Home Office Approval Letter")
    elif "employee" in data.value:
        classification.append("Reference Letters from previous employers")
    else:
        classification.append("Unknown")
print(file_names)
print(classification)
# Out:
# ['File Name', 'passport_surya.pdf', 'allen macwan - cv.pdf', 'signed offer letter_smitha.pdf', 'leela consultancy limited - employee payslip for jun-2022 for n priya.pdf', 'sheenam visa approval letter.pdf', 'visa approval email.pdf', 'certified brp.pdf', 'sureshresumeupdated (2).docx', 'passport first page.pdf', 'starter form.docx', 'approval letter.jpg', 'cv.pdf', 'cv.pdf', 'nupur priya rtwc.pdf', 'old brp.pdf', 'rafi certified passport.pdf', 'senior statistical programmers job description.pdf', 'hariharan starter form.docx', 'passport.pdf', 'not applicable - addendum.docx', 'sai krishna - test analyst cv.docx', 'compliance undertaking.pdf', 'pension enrolment letter .pdf', 'siddip_ neduri recording_19thnov,2022 640x360.mp4', 'leela starter form .docx', 'aamil interview video.mp4', 'aamil rtwc .pdf', 'addendum to employment agreement.pdf', 'addendum_shruthi.pdf', 'addendum_snehith.pdf', 'advert feedback - business consultant.xlsx', 'advert feedback - business consultant.xlsx', 'adv
# ...
